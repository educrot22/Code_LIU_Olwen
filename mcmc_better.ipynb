# %%
import jax
import numpyro
import numpy as np
import matplotlib.pyplot as plt
import numpyro_ext
#import numpyro.distributions as dist
#import numpyro_ext.distributions as distx, numpyro_ext.optim as optimx
import arviz as az
import corner
#import itertools
import scipy
import jax.numpy as jnp
import pandas as pd 
from jaxoplanet.orbits.keplerian import Central
from jaxoplanet.starry.surface import Surface
from jaxoplanet.starry.orbit import SurfaceSystem
import astropy.constants as const
# %matplotlib widget

from collections.abc import Callable
from functools import partial
from jaxoplanet.starry.orbit import SurfaceSystem
from jaxoplanet.orbits.keplerian import Central, Body
from jaxoplanet.types import Array, Scalar
from jaxoplanet.core.limb_dark import light_curve as _limb_dark_light_curve
from jaxoplanet.starry.core.basis import A1, A2_inv, U
from jaxoplanet.starry.core.polynomials import Pijk
from jaxoplanet.starry.core.rotation import left_project
from jaxoplanet.starry.core.solution import rT, solution_vector
from jaxoplanet.starry.surface import Surface 

# For multi-core parallelism (useful when running multiple MCMC chains in parallel)
numpyro.set_host_device_count(2)

# For CPU (use "gpu" for GPU)
numpyro.set_platform("cpu")

# For 64-bit precision since JAX defaults to 32-bit
jax.config.update("jax_enable_x64", True)

h = 6.62607015e-34  # Planck constant [J*s]
c = 2.99792458e8    # speed of light [m/s]
kB = 1.380649e-23   # Boltzmann constant [J/K]

# %%
def planck(lamb_m, T):
    """Planck function B_lambda in SI units."""
    a = 2*h*c**2 / (lamb_m**5)
    b = h*c / (lamb_m*kB*T)
    return a / (jnp.exp(b) - 1)

def surface_light_curve(
    surface: Surface,
    r: float | None = None,
    x: float | None = None,
    y: float | None = None,
    z: float | None = None,
    theta: float | None = None,
    order: int = 20,
    higher_precision: bool = False,
):
    """Light curve of an occulted surface.

    Args:
        surface (Surface): Surface object
        r (float or None): radius of the occulting body, relative to the current map
           body
        x (float or None): x coordinate of the occulting body relative to the surface
           center. By default (None) 0.0
        y (float or None): y coordinate of the occulting body relative to the surface
           center. By default (None) 0.0
        z (float or None): z coordinate of the occulting body relative to the surface
           center. By default (None) 0.0
        theta (float):
            rotation angle of the map, in radians. By default 0.0
        order (int):
            order of the P integral numerical approximation. By default 20
        higher_precision (bool): whether to compute change of basis matrix as hight
            precision. By default False (only used to testing).

    Returns:
        ArrayLike: flux
    """
    if higher_precision:
        try:
            from jaxoplanet.starry.multiprecision import (
                basis as basis_mp,
                utils as utils_mp,
            )
        except ImportError as e:
            raise ImportError(
                "The `mpmath` Python package is required for higher_precision=True."
            ) from e

    total_deg = surface.deg

    rT_deg = rT(total_deg)

    x = 0.0 if x is None else x
    y = 0.0 if y is None else y
    z = 0.0 if z is None else z

    # no occulting body
    if r is None:
        b_rot = True
        theta_z = 0.0
        design_matrix_p = rT_deg

    # occulting body
    else:
        b = jnp.sqrt(jnp.square(x) + jnp.square(y))
        b_rot = jnp.logical_or(jnp.greater_equal(b, 1.0 + r), jnp.less_equal(z, 0.0))
        b_occ = jnp.logical_not(b_rot)

        # trick to avoid nan `x=jnp.where...` grad caused by nan sT
        r = jnp.where(b_rot, 1.0, r)
        b = jnp.where(b_rot, 1.0, b)

        if surface.ydeg == 0:
            if surface.udeg == 0:
                ld_u = jnp.array([])
            else:
                ld_u = jnp.concatenate(
                    [jnp.atleast_1d(jnp.asarray(u_)) for u_ in surface.u], axis=0
                )

            lc_func = partial(_limb_dark_light_curve, ld_u, order=order)
            lc = lc_func(b, r)
            return surface.amplitude * (1.0 + jnp.where(b_occ, lc, 0))

        else:
            theta_z = jnp.arctan2(x, y)
            sT = solution_vector(total_deg, order=order)(b, r)

        if total_deg > 0:
            if higher_precision:
                A2 = np.atleast_2d(utils_mp.to_numpy(basis_mp.A2(total_deg)))
            else:
                A2 = scipy.sparse.linalg.inv(A2_inv(total_deg))
                A2 = jax.experimental.sparse.BCOO.from_scipy_sparse(A2)
        else:
            A2 = jnp.array([[1]])

        design_matrix_p = jnp.where(b_occ, sT @ A2, rT_deg)

    if surface.ydeg == 0:
        rotated_y = surface.y.todense()
    else:
        rotated_y = left_project(
            surface.ydeg,
            surface._inc,
            surface._obl,
            theta,
            theta_z,
            surface.y.todense(),
        )

    # limb darkening
    if surface.udeg == 0:
        p_u = Pijk.from_dense(jnp.array([1]))
    else:
        u = jnp.array([1, *surface.u])
        p_u = Pijk.from_dense(u @ U(surface.udeg), degree=surface.udeg)

    # surface map * limb darkening map
    if higher_precision:
        A1_val = np.atleast_2d(utils_mp.to_numpy(basis_mp.A1(surface.ydeg)))
    else:
        A1_val = jax.experimental.sparse.BCOO.from_scipy_sparse(A1(surface.ydeg))

    p_y = Pijk.from_dense(A1_val @ rotated_y, degree=surface.ydeg)
    p_yu = p_y * p_u
    norm = np.pi / (p_u.tosparse() @ rT(surface.udeg))

    return surface.amplitude * (p_yu.tosparse() @ design_matrix_p) * norm

def system_observable(surface_observable, flux_planet, flux_star, **kwargs):
    _surface_observable = partial(surface_observable, **kwargs)

    def observable_fun(
        system: SurfaceSystem,
    ) -> Callable[[Scalar], tuple[Array | None, Array | None]]:
        # the observable function of the central given the position and radii
        # of all other bodies
        central_bodies_observable = jax.vmap(
            _surface_observable, in_axes=(None, 0, 0, 0, 0, None)
        )

        # the observable function of all bodies combined given their position to the
        # central
        @partial(system.surface_vmap, in_axes=(0, 0, 0, 0, None))
        def compute_body_observable(surface, radius, x, y, z, time):
            if surface is None:
                return 0.0
            else:
                theta = surface.rotational_phase(time)
                return _surface_observable(
                    surface,
                    (system.central.radius / radius),
                    (x / radius),
                    (y / radius),
                    (z / radius),
                    theta,
                )

        @partial(jnp.vectorize, signature="()->(n)")
        def observable_impl(time: Scalar) -> Array:
            # a function that give the array of observables for all bodies, starting
            # with the central
            if system.central_surface is None:
                central_light_curves = jnp.array([0.0])
            else:
                theta = system.central_surface.rotational_phase(time)
                central_radius = system.central.radius
                central_phase_curve = _surface_observable(
                    system.central_surface, theta=theta
                )
                if len(system.bodies) > 0:
                    xos, yos, zos = system.relative_position(time)
                    n = len(xos)
                    central_light_curves = central_bodies_observable(
                        system.central_surface,
                        (system.radius / central_radius),
                        (xos / central_radius),
                        (yos / central_radius),
                        (zos / central_radius),
                        theta,
                    )
                    def phase_planet(time,P,t0=0):
                        phase = jnp.sin(((time+t0)/P)*2*jnp.pi - jnp.pi/2)/2+0.5 
                        return phase
                    if n > 1 and central_light_curves is not None:
                        central_light_curves = central_light_curves.sum(
                            0
                        ) - central_phase_curve * (n - 1)
                        central_light_curves = jnp.expand_dims(central_light_curves, 0)

                    body_light_curves = compute_body_observable(
                        system.radius, -xos, -yos, -zos, time
                    )
                    in_eclipse = jnp.logical_not(body_light_curves)
                    body_light_curves_2 = (flux_planet/flux_star)*phase_planet(time,system.bodies[0].period)*(system.bodies[0].radius/system.central.radius)**2 * (-1*in_eclipse+1) 
                    #body_light_curves_2 = body_light_curves_2/jnp.max(body_light_curves_2)
                    return jnp.hstack([central_light_curves, body_light_curves_2])
                else:
                    return jnp.array([central_phase_curve])

        return observable_impl

    return observable_fun

def light_curve(system, flux_planet, flux_star, order=20):
    return system_observable(surface_light_curve, flux_planet, flux_star, order=order)(system)

# %%
def fast_binning(x, y, bins, error=None, std=False):
    bins = np.arange(np.min(x), np.max(x), bins)
    d = np.digitize(x, bins)

    n = np.max(d) + 2

    binned_x = np.empty(n)
    binned_y = np.empty(n)
    binned_error = np.empty(n)

    binned_x[:] = -np.pi
    binned_y[:] = -np.pi
    binned_error[:] = -np.pi

    for i in range(0, n):
        s = np.where(d == i)
        if len(s[0]) > 0:
            s = s[0]
            binned_y[i] = np.mean(y[s])
            binned_x[i] = np.mean(x[s])
            binned_error[i] = np.std(y[s]) / np.sqrt(len(s))

            if error is not None:
                err = error[s]
                binned_error[i] = np.sqrt(np.sum(np.power(err, 2))) / len(err)
            else:
                binned_error[i] = np.std(y[s]) / np.sqrt(len(s))

    nans = binned_x == -np.pi
    
    return binned_x[~nans], binned_y[~nans], binned_error[~nans]

# %%
df = pd.read_pickle("LHS3844b_0.0_1obs.pickle")
wvl = df['data'].keys()

df2 = pd.read_pickle("LHS3844b_phase_curve_max_1obs.pickle")
yerr = df2['datasets'][b'AIRS-Ch0-2']['lc']['flux_error'][0]

P=df2['theta'][3]
R_star = df2['theta'][0]
M_star = df2['theta'][2]
time_transit = 0
r = df2['theta'][6]
R = df2['theta'][6]*R_star
print(R)
T_star = df2['theta'][1]
T_planet = df2['theta'][8]
print(T_planet)
uu = np.array([0.45, 0.05]) # Quadratic limb-darkening coefficients

def light_curve_model(time, lamb, R, T_planet, T_star, P, R_star, M_star, time_transit, uu): # light_curve_model(time, time_transit, P, R_star, M_star, R, T_star, T_planet, uu)
    star = Central(radius=R_star, mass=M_star)
    planet = Body(radius=R, time_transit=time_transit, period=P)
    m = Surface(u=uu)
    system = SurfaceSystem(star, m).add_body(planet, m)
    flux_star = planck(lamb*1e-6, jnp.mean(T_star))
    flux_planet = planck(lamb*1e-6, jnp.mean(T_planet))
    pc = light_curve(system, flux_planet, flux_star)(time)[:,1] + light_curve(system, flux_planet, flux_star)(time)[:,0]
    #pc = pc/np.max(pc)
    return pc

instru = df2['datasets'].keys()
instru = list(instru)
instru.pop(0)

"""fig, ax = plt.subplots(dpi=200)
offset = 0.0
for i, inst in enumerate(instru) : 
    time = df2['datasets'][inst]['lc']['time'] - 2458828.93
    pc = df2['datasets'][inst]['lc']['model']
    second_binned = fast_binning(time, df2['datasets'][inst]['lc']['ariel'], 2/(60*24))
    ax.errorbar(second_binned[0], second_binned[1] + offset, yerr=second_binned[2], c=(1, 1, 0.2), fmt='.')
    ax.plot(time, light_curve_model(time, list(wvl)[i], R, T_planet, T_star, P, R_star, M_star, time_transit, uu) + offset)
    ax.annotate(rf'$\lambda$ = {list(wvl)[i]} $\mu$m ({str(inst)})', xy=(0.1, 1.002 + offset), fontsize=8)
    offset += 0.01
plt.title(rf'Phase curves')
plt.legend()
plt.xlabel(r'BJD$_{TDB}$ - 2,458,829 [d]')
plt.ylabel(r'$\frac{F_p + F_{\star}}{F_{\star}}$')
plt.show()"""
# Out:
# 0.0120015
# 1031.2476166730817
# "fig, ax = plt.subplots(dpi=200)\noffset = 0.0\nfor i, inst in enumerate(instru) : \n    time = df2['datasets'][inst]['lc']['time'] - 2458828.93\n    pc = df2['datasets'][inst]['lc']['model']\n    second_binned = fast_binning(time, df2['datasets'][inst]['lc']['ariel'], 2/(60*24))\n    ax.errorbar(second_binned[0], second_binned[1] + offset, yerr=second_binned[2], c=(1, 1, 0.2), fmt='.')\n    ax.plot(time, light_curve_model(time, list(wvl)[i], R, T_planet, T_star, P, R_star, M_star, time_transit, uu) + offset)\n    ax.annotate(rf'$\\lambda$ = {list(wvl)[i]} $\\mu$m ({str(inst)})', xy=(0.1, 1.002 + offset), fontsize=8)\n    offset += 0.01\nplt.title(rf'Phase curves')\nplt.legend()\nplt.xlabel(r'BJD$_{TDB}$ - 2,458,829 [d]')\nplt.ylabel(r'$\x0crac{F_p + F_{\\star}}{F_{\\star}}$')\nplt.show()"

# %%
#df = pd.read_pickle("LHS3844b_0.0_1obs.pickle")
df2 = pd.read_pickle("LHS3844b_phase_curve_max_1obs.pickle")

#print(df) 
print(type(df2))
print(len(df2))
print(df2.keys())
print(df2['parameters'])
print(df2['pl_type'])
print(df2['theta'])
print(df2['num_obs'])
print(df2['datasets'][b'AIRS-CH1'])
#print(df['input_parameters'])
print(df2['datasets'][b'VISPhot']['lc'])#['lc'])
#print(df['data'].keys())


time_2 = df2['datasets'][b'VISPhot']['lc']['time'] - 2458828.93
pc_2 = df2['datasets'][b'VISPhot']['lc']['model'] #+ df2['datasets'][b'VISPhot']['lc']['therm_pc']

instru = df2['datasets'].keys()
print(instru)
instru = list(instru)
instru.pop(0)

plt.rcParams.update({
    'xtick.labelsize': 14,
    'ytick.labelsize': 14
})

dataset = {}
for i, inst in enumerate(instru) : 
    time = df2['datasets'][inst]['lc']['time'] - 2458828.93
    pc = df2['datasets'][inst]['lc']['model']
    dataset[list(wvl)[i]] = [time, df2['datasets'][inst]['lc']['ariel'], df2['datasets'][inst]['lc']['flux_error']]
    second_binned = fast_binning(time, df2['datasets'][inst]['lc']['ariel'], 0.01, error = np.array(df2['datasets'][inst]['lc']['flux_error']))
    plt.figure()
    plt.errorbar(time, df2['datasets'][inst]['lc']['ariel'], yerr=df2['datasets'][inst]['lc']['flux_error'], c=(1, 1, 0.2), fmt='.', label='data')
    plt.errorbar(second_binned[0], second_binned[1], yerr=second_binned[2], c=(1, 0.5, 0), fmt='o', label='data binned', zorder=3)
    plt.plot(time, light_curve_model(time, list(wvl)[i], R, T_planet, T_star, P, R_star, M_star, time_transit, uu), label='our model', zorder=10)
    plt.plot(time, pc, 'k', label='origin data', zorder=5)
    plt.title(rf'Phase curve at $\lambda$ = {list(wvl)[i]} $\mu$m with {str(inst)[2:-1]}', fontsize=16)
    plt.legend(fontsize=12)
    plt.xlabel(r'BJD$_{TDB}$ - 2,458,829 [d]', fontsize=14)
    plt.ylabel(r'$(F_p + F_{\bigstar})/F_{\bigstar}$', fontsize=14)
    plt.savefig(f"model_{str(inst)[2:-1]}.svg")
    plt.show()
# Out:
# <class 'dict'>
# 5
# dict_keys(['datasets', 'pl_type', 'parameters', 'theta', 'num_obs'])
# {'Rs': {'index': 0}, 'Ts': {'index': 1}, 'Ms': {'index': 2}, 'P': {'index': 3}, 'T0': {'index': 4}, 'i': {'index': 5}, 'Rp/Rs': {'index': 6}, 'HSO': {'index': 7}, 'Td': {'index': 8}, 'Tn': {'index': 9}, 'A_g': {'index': 10}}
# max
# [1.89000000e-01 3.03600000e+03 1.51000000e-01 4.62929640e-01
#  2.45882893e+06 8.85000000e+01 6.35000000e-02 0.00000000e+00
#  1.03124762e+03 5.00000000e+01 0.00000000e+00]
# 1
# {'exp_time': np.float64(35.65215537321777), 'min_wl': np.float64(3.9), 'max_wl': np.float64(8.023322839739118), 'dead_time': 0.2, 'model_time': 900.0, 'lc':               time     phase  ref_pc  therm_pc  transit     model  flux_error  \
# 0     2.458829e+06  1.727774       0  0.000245      0.0  1.000245    0.000719
# 1     2.458829e+06  1.733406       0  0.000246      0.0  1.000246    0.000719
# 2     2.458829e+06  1.739038       0  0.000247      0.0  1.000247    0.000719
# 3     2.458829e+06  1.744670       0  0.000248      0.0  1.000248    0.000719
# 4     2.458829e+06  1.750302       0  0.000250      0.0  1.000250    0.000719
# ...            ...       ...     ...       ...      ...       ...         ...
# 1613  2.458830e+06  4.529082       0  0.000250      0.0  1.000250    0.000719
# 1614  2.458830e+06  4.534714       0  0.000249      0.0  1.000249    0.000719
# 1615  2.458830e+06  4.540346       0  0.000248      0.0  1.000248    0.000719
# 1616  2.458830e+06  4.545978       0  0.000247      0.0  1.000247    0.000719
# 1617  2.458830e+06  4.551610       0  0.000246      0.0  1.000246    0.000719
#
#          ariel
# 0     0.999890
# 1     0.998977
# 2     1.000798
# 3     1.000313
# 4     1.000366
# ...        ...
# 1613  1.000914
# 1614  0.999568
# 1615  1.000937
# 1616  0.999908
# 1617  1.001096
#
# [1618 rows x 8 columns], 'lc_binned':             time     phase  ref_pc  therm_pc  transit     model  flux_error  \
# 0   2.458829e+06  1.795359     0.0  0.000259      0.0  1.000259    0.000144
# 1   2.458829e+06  1.936160     0.0  0.000287      0.0  1.000287    0.000144
# 2   2.458829e+06  2.076961     0.0  0.000314      0.0  1.000314    0.000144
# 3   2.458829e+06  2.217762     0.0  0.000339      0.0  1.000339    0.000144
# 4   2.458829e+06  2.358564     0.0  0.000362      0.0  1.000362    0.000144
# ..           ...       ...     ...       ...      ...       ...         ...
# 60  2.458830e+06  3.960245     0.0  0.000356      0.0  1.000356    0.000144
# 61  2.458830e+06  4.101046     0.0  0.000333      0.0  1.000333    0.000144
# 62  2.458830e+06  4.241848     0.0  0.000308      0.0  1.000308    0.000144
# 63  2.458830e+06  4.382649     0.0  0.000280      0.0  1.000280    0.000144
# 64  2.458830e+06  4.503738     0.0  0.000256      0.0  1.000256    0.000144
#
#        ariel
# 0   1.000104
# 1   1.000340
# 2   1.000316
# 3   1.000476
# 4   1.000493
# ..       ...
# 60  1.000750
# 61  1.000497
# 62  1.000120
# 63  1.000101
# 64  1.000253
#
# [65 rows x 8 columns]}
#              time     phase  ref_pc      therm_pc  transit  model  flux_error  \
# 0    2.458829e+06  1.727774     0.0  2.389529e-10      0.0    1.0     0.00621
# 1    2.458829e+06  1.737231     0.0  2.408817e-10      0.0    1.0     0.00621
# 2    2.458829e+06  1.746688     0.0  2.428073e-10      0.0    1.0     0.00621
# 3    2.458829e+06  1.756145     0.0  2.447298e-10      0.0    1.0     0.00621
# 4    2.458829e+06  1.765602     0.0  2.466488e-10      0.0    1.0     0.00621
# ..            ...       ...     ...           ...      ...    ...         ...
# 959  2.458830e+06  4.513731     0.0  2.474296e-10      0.0    1.0     0.00621
# 960  2.458830e+06  4.523188     0.0  2.455120e-10      0.0    1.0     0.00621
# 961  2.458830e+06  4.532645     0.0  2.435909e-10      0.0    1.0     0.00621
# 962  2.458830e+06  4.542102     0.0  2.416666e-10      0.0    1.0     0.00621
# 963  2.458830e+06  4.551558     0.0  2.397391e-10      0.0    1.0     0.00621
#
#         ariel
# 0    1.005562
# 1    0.995224
# 2    0.988492
# 3    0.997283
# 4    1.006709
# ..        ...
# 959  1.006750
# 960  1.008860
# 961  0.993880
# 962  1.015248
# 963  0.993618
#
# [964 rows x 8 columns]
# dict_keys([b'VISPhot', b'FGS1', b'FGS2', b'NIRSpec', b'AIRS-Ch0-1', b'AIRS-Ch0-2', b'AIRS-CH1'])
# Canvas(toolbar=Toolbar(toolitems=[('Home', 'Reset original view', 'home', 'home'), ('Back', 'Back to previous …
# Canvas(toolbar=Toolbar(toolitems=[('Home', 'Reset original view', 'home', 'home'), ('Back', 'Back to previous …
# Canvas(toolbar=Toolbar(toolitems=[('Home', 'Reset original view', 'home', 'home'), ('Back', 'Back to previous …
# Canvas(toolbar=Toolbar(toolitems=[('Home', 'Reset original view', 'home', 'home'), ('Back', 'Back to previous …
# Canvas(toolbar=Toolbar(toolitems=[('Home', 'Reset original view', 'home', 'home'), ('Back', 'Back to previous …
# Canvas(toolbar=Toolbar(toolitems=[('Home', 'Reset original view', 'home', 'home'), ('Back', 'Back to previous …

# %%
2/(60*24)
# Out:
# 0.001388888888888889

# %%
print(dataset[5.96][2])
# Out:
# 0       0.000719
# 1       0.000719
# 2       0.000719
# 3       0.000719
# 4       0.000719
#           ...
# 1613    0.000719
# 1614    0.000719
# 1615    0.000719
# 1616    0.000719
# 1617    0.000719
# Name: flux_error, Length: 1618, dtype: float64

# %%
def mcmc(lamb, P, R_star, M_star, time_transit, R_planet, T_star, T_planet, uu):
        time = dataset[lamb][0]
        observed = dataset[lamb][1]
        yerr_array = dataset[lamb][2]
        yerr = dataset[lamb][2][0]
        def MCMC_model(time, yerr, y=None):
            # Priors for the parameters we're fitting for

            # The radius of the planet
            r = numpyro.sample("r", numpyro.distributions.Normal(R_planet, 0.01))

            # The radius of the star
            R_star_prior = numpyro.sample("R_star", numpyro.distributions.Normal(R_star, 0.05))

            # The star temperature
            T_star_prior = numpyro.sample("T_star", numpyro.distributions.Normal(T_star, 10))

            # The planet temperature
            T_planet_prior = numpyro.sample("T_planet", numpyro.distributions.Normal(T_planet, 200))

            u1 = numpyro.sample("u1", numpyro.distributions.Normal(uu[0], 0.2))

            u2 = numpyro.sample("u2", numpyro.distributions.Normal(uu[1], 0.2))

            # The orbit and light curve
            y_pred = light_curve_model(time, lamb, r, T_planet_prior, T_star_prior, P, R_star_prior, M_star, time_transit, (u1, u2))

            # Let's track the light curve
            numpyro.deterministic("light_curve", y_pred)

            # The likelihood function assuming Gaussian uncertainty
            numpyro.sample("obs", numpyro.distributions.Normal(y_pred, yerr), obs=y)

        n_prior_samples = 3000
        prior_samples = numpyro.infer.Predictive(MCMC_model, num_samples=n_prior_samples)(jax.random.PRNGKey(0), time, yerr)

        # Let's make it into an arviz InferenceData object.
        # To do so we'll first need to reshape the samples to be of shape (chains, draws, *shape)
        converted_prior_samples = {
            f"{p}": np.expand_dims(prior_samples[p], axis=0) for p in prior_samples
        }
        prior_samples_inf_data = az.from_dict(converted_prior_samples)
        fig = plt.figure(figsize=(12, 12))
        _ = corner.corner(
            prior_samples_inf_data,
            fig=fig,
            var_names=["r", "T_planet", "R_star", "T_star", "u1", "u2"],
            truths=[R_planet, T_planet, R_star, T_star, uu[0], uu[1]],
            show_titles=True,
            title_kwargs={"fontsize": 10},
            label_kwargs={"fontsize": 10},
        )
        plt.savefig(f"priors_{str(lamb)}.svg")
        init_param_method = "true_values"  # "prior_median" or "true_values"

        if init_param_method == "prior_median":
            print("Starting from the prior medians")
            run_optim = numpyro_ext.optim.optimize(
                MCMC_model, init_strategy=numpyro.infer.init_to_median()
            )
        elif init_param_method == "true_values":
            print("Starting from the true values")
            init_params = {
                #"t0": float(time_transit),
                #"logP": jnp.log(P),
                "r": R_planet,
                #"logM": jnp.log(M_star),
                "R_star" : R_star,
                "T_star" : float(T_star),
                "T_planet" : float(T_planet),
                "u1": uu[0],
                "u2": uu[1],
            }
            run_optim = numpyro_ext.optim.optimize(
                MCMC_model,
                init_strategy=numpyro.infer.init_to_value(values=init_params),
            )

        time = jnp.asarray(time, dtype=jnp.float64)
        yerr = jnp.asarray(yerr, dtype=jnp.float64)
        observed = jnp.asarray(observed, dtype=jnp.float64)

        opt_params = run_optim(jax.random.PRNGKey(3), time, yerr, y=observed)
        for k, v in opt_params.items():
            if k in ["light_curve", "obs"]:
                continue
            print(f"optimized value of {k}: {v}")
        sampler = numpyro.infer.MCMC(
        numpyro.infer.NUTS(
            MCMC_model,
            dense_mass=True,
            regularize_mass_matrix=True,
            init_strategy=numpyro.infer.init_to_value(values=opt_params),
        ),
        num_warmup=500,
        num_samples=1000,
        num_chains=1,
        progress_bar=True,
        )

        sampler.run(jax.random.PRNGKey(1), time, yerr, y=observed)
        inf_data = az.from_numpyro(sampler)
        fig = plt.figure(figsize=(12, 12))
        _ = corner.corner(
            inf_data,
            var_names=["r", "T_planet", "R_star", "T_star", "u1", "u2"],
            truths=[R, T_planet, R_star, T_star, uu[0], uu[1]],
            show_titles=True,
            quantiles=[0.16, 0.5, 0.84],
            title_kwargs={"fontsize": 10},
            label_kwargs={"fontsize": 10},
            title_fmt=".10f",
            fig=fig,
        )
        plt.savefig(f"posteriors_{str(lamb)}.svg")
        samples = sampler.get_samples()
        r_percentiles = np.percentile(samples["r"], [16, 50, 84], axis=0)
        r_minus = r_percentiles[1]-r_percentiles[0]
        r_plus = r_percentiles[2]-r_percentiles[1]
        R_mcmc = r_percentiles[1]
        R_star_percentiles = np.percentile(samples["R_star"], [16, 50, 84], axis=0)
        R_star_minus = R_star_percentiles[1]-R_star_percentiles[0]
        R_star_plus = R_star_percentiles[2]-R_star_percentiles[1]
        R_star_mcmc = R_star_percentiles[1]
        T_percentiles = np.percentile(samples["T_planet"], [16, 50, 84], axis=0)
        T_minus = T_percentiles[1]-T_percentiles[0]
        T_plus = T_percentiles[2]-T_percentiles[1]
        T_mcmc = T_percentiles[1]
        T_star_percentiles = np.percentile(samples["T_star"], [16, 50, 84], axis=0)
        T_star_minus = T_star_percentiles[1]-T_star_percentiles[0]
        T_star_plus = T_star_percentiles[2]-T_star_percentiles[1]
        T_star_mcmc = T_star_percentiles[1]
        u1_percentiles = np.percentile(samples["u1"], [16, 50, 84], axis=0)
        u1_minus = u1_percentiles[1]-u1_percentiles[0]
        u1_plus = u1_percentiles[2]-u1_percentiles[1]
        u1_mcmc = u1_percentiles[1]
        u2_percentiles = np.percentile(samples["u2"], [16, 50, 84], axis=0)
        u2_minus = u2_percentiles[1]-u2_percentiles[0]
        u2_plus = u2_percentiles[2]-u2_percentiles[1]
        u2_mcmc = u2_percentiles[1]

        plt.figure()
        plt.plot(time, light_curve_model(time, lamb, R_planet, T_planet, T_star, P, R_star, M_star, time_transit, uu), label='truth', zorder=3)
        plt.plot(time, light_curve_model(time, lamb, R_mcmc, T_mcmc, T_star_mcmc, P, R_star_mcmc, M_star, time_transit, (u1_mcmc, u2_mcmc)), "--C0", label="MCMC result", zorder=3)
        plt.errorbar(time, observed, yerr=yerr_array, fmt='o', label='data')
        plt.title(rf'Phase curve at $\lambda$ = {lamb} $\mu$m')
        plt.legend()
        plt.xlabel(r'BJD$_{TDB}$ - 2,458,829 [d]')
        plt.ylabel(r'$\frac{F_p + F_{\star}}{F_{\star}}$')
        plt.show()
        return {"R" : (r_minus, r_plus, R_mcmc), "T_planet" : (T_minus, T_plus, T_mcmc), "T_star" : (T_star_minus, T_star_plus, T_star_mcmc),
                 "u1" : (u1_minus, u1_plus, u1_mcmc), "u2" : (u2_minus, u2_plus, u2_mcmc)}

# %%
radii = []
radii_plus = []
radii_minus = []
Temps = []
Temps_plus = []
Temps_minus = []
eclipse_depths_2 = []
eclipse_minus_2 = []
eclipse_plus_2 = []
u1 = []
u1_plus = []
u1_minus = []
u2 = []
u2_plus = []
u2_minus = []
for i, inst in enumerate(instru) : 
    #time = df2['datasets'][inst]['lc']['time'] - 2458828.93
    #pc = df2['datasets'][inst]['lc']['model']
    #binned = fast_binning(time, df2['datasets'][inst]['lc']['ariel'], 2/(60*24), error=np.array(df2['datasets'][inst]['lc']['flux_error']))
    if i != 0:
        data = mcmc(list(wvl)[i], P, R_star, M_star, time_transit, R, T_star, T_planet, uu)
        print(data)
        radii_minus.append(data["R"][0])
        radii_plus.append(data["R"][1])
        radii.append(data["R"][2])
        Temps_minus.append(data["T_planet"][0])
        Temps_plus.append(data["T_planet"][1])
        Temps.append(data["T_planet"][2])
        eclipse_depths_2.append(data["eclipse_depth"][0])
        eclipse_minus_2.append(data["eclipse_depth"][1])
        eclipse_plus_2.append(data["eclipse_depth"][2])
        u1.append(data["u1"][0])
        u1_plus.append(data["u1"][1])
        u1_minus.append(data["u1"][2])
        u2.append(data["u2"][0])
        u2_plus.append(data["u2"][1])
        u2_minus.append(data["u2"][2])
# Out:
# Starting from the true values
# ---------------------------------------------------------------------------
# KeyboardInterrupt                         Traceback (most recent call last)
# Cell In[16], line 21
#      16 for i, inst in enumerate(instru) :
#      17     #time = df2['datasets'][inst]['lc']['time'] - 2458828.93
#      18     #pc = df2['datasets'][inst]['lc']['model']
#      19     #binned = fast_binning(time, df2['datasets'][inst]['lc']['ariel'], 2/(60*24), error=np.array(df2['datasets'][inst]['lc']['flux_error']))
#      20     if i != 0:
# ---> 21         data = mcmc(list(wvl)[i], P, R_star, M_star, time_transit, R, T_star, T_planet, uu)
#      22         print(data)
#      23         radii_minus.append(data["R"][0])
#
# Cell In[15], line 83, in mcmc(lamb, P, R_star, M_star, time_transit, R_planet, T_star, T_planet, uu)
#      80 yerr = jnp.asarray(yerr, dtype=jnp.float64)
#      81 observed = jnp.asarray(observed, dtype=jnp.float64)
# ---> 83 opt_params = run_optim(jax.random.PRNGKey(3), time, yerr, y=observed)
#      84 for k, v in opt_params.items():
#      85     if k in ["light_curve", "obs"]:
#
# File ~/venvs/jaxoenv/lib/python3.11/site-packages/numpyro_ext/optim.py:84, in optimize.<locals>.run(rng_key, *args, **kwargs)
#      82 def run(rng_key, *args, **kwargs):
#      83     init_key, sample_key, pred_key = jax.random.split(rng_key, 3)
# ---> 84     state = svi.init(init_key, *args, **kwargs)
#      85     for _ in range(num_steps):
#      86         state, _ = svi.update(state, *args, **kwargs)
#
# File ~/venvs/jaxoenv/lib/python3.11/site-packages/numpyro/infer/svi.py:184, in SVI.init(self, rng_key, init_params, *args, **kwargs)
#     182 if init_params is not None:
#     183     guide_init = substitute(guide_init, init_params)
# --> 184 guide_trace = trace(guide_init).get_trace(*args, **kwargs, **self.static_kwargs)
#     185 init_guide_params = {
#     186     name: site["value"]
#     187     for name, site in guide_trace.items()
#     188     if site["type"] == "param"
#     189 }
#     190 if init_params is not None:
#
# File ~/venvs/jaxoenv/lib/python3.11/site-packages/numpyro/handlers.py:193, in trace.get_trace(self, *args, **kwargs)
#     185 def get_trace(self, *args, **kwargs) -> TraceT:
#     186     """
#     187     Run the wrapped callable and return the recorded trace.
#     188
#    (...)    191     :return: `OrderedDict` containing the execution trace.
#     192     """
# --> 193     self(*args, **kwargs)
#     194     return self.trace
#
# File ~/venvs/jaxoenv/lib/python3.11/site-packages/numpyro/primitives.py:119, in Messenger.__call__(self, *args, **kwargs)
#     117     return self
#     118 with self:
# --> 119     return self.fn(*args, **kwargs)
#
# File ~/venvs/jaxoenv/lib/python3.11/site-packages/numpyro/handlers.py:849, in seed.__call__(self, *args, **kwargs)
#     845     cloned_seeded_fn = seed(
#     846         self.fn, rng_seed=self.rng_key, hide_types=self.hide_types
#     847     )
#     848     cloned_seeded_fn.stateful = True
# --> 849     return cloned_seeded_fn.__call__(*args, **kwargs)
#     850 return super().__call__(*args, **kwargs)
#
# File ~/venvs/jaxoenv/lib/python3.11/site-packages/numpyro/handlers.py:850, in seed.__call__(self, *args, **kwargs)
#     848     cloned_seeded_fn.stateful = True
#     849     return cloned_seeded_fn.__call__(*args, **kwargs)
# --> 850 return super().__call__(*args, **kwargs)
#
# File ~/venvs/jaxoenv/lib/python3.11/site-packages/numpyro/primitives.py:119, in Messenger.__call__(self, *args, **kwargs)
#     117     return self
#     118 with self:
# --> 119     return self.fn(*args, **kwargs)
#
# File ~/venvs/jaxoenv/lib/python3.11/site-packages/numpyro_ext/optim.py:199, in AutoDelta.__call__(self, *args, **kwargs)
#     197 def __call__(self, *args, **kwargs):
#     198     if self.prototype_trace is None:
# --> 199         self._setup_prototype(*args, **kwargs)
#     201     plates = self._create_plates(*args, **kwargs)
#     202     result = {}
#
# File ~/venvs/jaxoenv/lib/python3.11/site-packages/numpyro/infer/autoguide.py:530, in AutoDelta._setup_prototype(self, *args, **kwargs)
#     529 def _setup_prototype(self, *args, **kwargs):
# --> 530     super()._setup_prototype(*args, **kwargs)
#     531     with numpyro.handlers.block():
#     532         self._init_locs = {
#     533             k: v
#     534             for k, v in self._postprocess_fn(self._init_locs).items()
#     535             if k in self._init_locs
#     536         }
#
# File ~/venvs/jaxoenv/lib/python3.11/site-packages/numpyro/infer/autoguide.py:160, in AutoGuide._setup_prototype(self, *args, **kwargs)
#     153 rng_key = numpyro.prng_key()
#     154 with handlers.block():
#     155     (
#     156         init_params,
#     157         self._potential_fn_gen,
#     158         postprocess_fn_gen,
#     159         self.prototype_trace,
# --> 160     ) = initialize_model(
#     161         rng_key,
#     162         self.model,
#     163         init_strategy=self.init_loc_fn,
#     164         dynamic_args=True,
#     165         model_args=args,
#     166         model_kwargs=kwargs,
#     167     )
#     168 self._potential_fn = self._potential_fn_gen(*args, **kwargs)
#     169 postprocess_fn = postprocess_fn_gen(*args, **kwargs)
#
# File ~/venvs/jaxoenv/lib/python3.11/site-packages/numpyro/infer/util.py:751, in initialize_model(rng_key, model, init_strategy, dynamic_args, model_args, model_kwargs, forward_mode_differentiation, validate_grad)
#     749     init_strategy = _init_to_unconstrained_value(values=unconstrained_values)
#     750 prototype_params = transform_fn(inv_transforms, constrained_values, invert=True)
# --> 751 (init_params, pe, grad), is_valid = find_valid_initial_params(
#     752     rng_key,
#     753     substitute(
#     754         model,
#     755         data={
#     756             k: site["value"]
#     757             for k, site in model_trace.items()
#     758             if site["type"] in ["plate"]
#     759         },
#     760     ),
#     761     init_strategy=init_strategy,
#     762     enum=has_enumerate_support,
#     763     model_args=model_args,
#     764     model_kwargs=model_kwargs,
#     765     prototype_params=prototype_params,
#     766     forward_mode_differentiation=forward_mode_differentiation,
#     767     validate_grad=validate_grad,
#     768 )
#     770 if not_jax_tracer(is_valid):
#     771     if device_get(~jnp.all(is_valid)):
#
# File ~/venvs/jaxoenv/lib/python3.11/site-packages/numpyro/infer/util.py:473, in find_valid_initial_params(rng_key, model, init_strategy, enum, model_args, model_kwargs, prototype_params, forward_mode_differentiation, validate_grad)
#     471 # Handle possible vectorization
#     472 if is_prng_key(rng_key):
# --> 473     (init_params, pe, z_grad), is_valid = _find_valid_params(
#     474         rng_key, exit_early=True
#     475     )
#     476 else:
#     477     (init_params, pe, z_grad), is_valid = lax.map(_find_valid_params, rng_key)
#
# File ~/venvs/jaxoenv/lib/python3.11/site-packages/numpyro/infer/util.py:459, in find_valid_initial_params.<locals>._find_valid_params(rng_key, exit_early)
#     455 init_state = (0, rng_key, (prototype_params, 0.0, prototype_grads), False)
#     456 if exit_early and not_jax_tracer(rng_key):
#     457     # Early return if valid params found. This is only helpful for single chain,
#     458     # where we can avoid compiling body_fn in while_loop.
# --> 459     _, _, (init_params, pe, z_grad), is_valid = init_state = body_fn(init_state)
#     460     if not_jax_tracer(is_valid):
#     461         if device_get(is_valid):
#
# File ~/venvs/jaxoenv/lib/python3.11/site-packages/numpyro/infer/util.py:443, in find_valid_initial_params.<locals>.body_fn(state)
#     441     z_grad = jacfwd(potential_fn)(params)
#     442 else:
# --> 443     pe, z_grad = value_and_grad(potential_fn)(params)
#     444 z_grad_flat = ravel_pytree(z_grad)[0]
#     445 is_valid = jnp.isfinite(pe) & jnp.all(jnp.isfinite(z_grad_flat))
#
#     [... skipping hidden 1 frame]
#
# File ~/venvs/jaxoenv/lib/python3.11/site-packages/jax/_src/api.py:479, in value_and_grad.<locals>.value_and_grad_f(*args, **kwargs)
#     477   _check_input_dtype_grad(holomorphic, allow_int, leaf)
#     478 if not has_aux:
# --> 479   ans, vjp_py = _vjp(f_partial, *dyn_args)
#     480 else:
#     481   ans, vjp_py, aux = _vjp(f_partial, *dyn_args, has_aux=True)
#
# File ~/venvs/jaxoenv/lib/python3.11/site-packages/jax/_src/api.py:2144, in _vjp(fun, has_aux, *primals)
#    2142 if not has_aux:
#    2143   flat_fun, out_tree = flatten_fun_nokwargs(fun, in_tree)
# -> 2144   out_primals, vjp = ad.vjp(flat_fun, primals_flat)
#    2145   out_tree = out_tree()
#    2146 else:
#
# File ~/venvs/jaxoenv/lib/python3.11/site-packages/jax/_src/interpreters/ad.py:312, in vjp(traceable, primals, has_aux)
#     310 def vjp(traceable: lu.WrappedFun, primals, has_aux=False):
#     311   if not has_aux:
# --> 312     out_primals, pvals, jaxpr, consts = linearize(traceable, *primals)
#     313   else:
#     314     out_primals, pvals, jaxpr, consts, aux = linearize(traceable, *primals, has_aux=True)
#
# File ~/venvs/jaxoenv/lib/python3.11/site-packages/jax/_src/interpreters/ad.py:286, in linearize(traceable, *primals, **kwargs)
#     284 has_aux = kwargs.pop('has_aux', False)
#     285 if config.use_direct_linearize.value:
# --> 286   return direct_linearize(traceable, primals, kwargs, has_aux=has_aux)
#     287 if not has_aux:
#     288   jvpfun = jvp(traceable)
#
# File ~/venvs/jaxoenv/lib/python3.11/site-packages/jax/_src/interpreters/ad.py:259, in direct_linearize(traceable, primals, kwargs, has_aux, tag)
#     254   aux_primals = [x.primal
#     255                  if isinstance(x, LinearizeTracer)
#     256                  and x._trace.tag is linearize_trace.tag
#     257                  else x for x in aux]
#     258 else:
# --> 259   ans = traceable.call_wrapped(*tracers)
#     260   aux = None
#     261 out_primals, out_tangents = unzip2(map(linearize_trace.to_primal_tangent_pair, ans))
#
# File ~/venvs/jaxoenv/lib/python3.11/site-packages/jax/_src/linear_util.py:212, in WrappedFun.call_wrapped(self, *args, **kwargs)
#     210 def call_wrapped(self, *args, **kwargs):
#     211   """Calls the transformed function"""
# --> 212   return self.f_transformed(*args, **kwargs)
#
# File ~/venvs/jaxoenv/lib/python3.11/site-packages/jax/_src/api_util.py:90, in flatten_fun_nokwargs(f, store, in_tree, *args_flat)
#      86 @lu.transformation_with_aux2
#      87 def flatten_fun_nokwargs(f: Callable, store: lu.Store,
#      88                          in_tree: PyTreeDef, *args_flat):
#      89   py_args = tree_unflatten(in_tree, args_flat)
# ---> 90   ans = f(*py_args)
#      91   ans, out_tree = tree_flatten(ans)
#      92   store.store(out_tree)
#
# File ~/venvs/jaxoenv/lib/python3.11/site-packages/jax/_src/api_util.py:288, in _argnums_partial(_fun, _dyn_argnums, _fixed_args, *dyn_args, **kwargs)
#     286 args = [next(fixed_args_).val if x is sentinel else x for x in args]
#     287 assert next(fixed_args_, sentinel) is sentinel
# --> 288 return _fun(*args, **kwargs)
#
# File ~/venvs/jaxoenv/lib/python3.11/site-packages/jax/_src/linear_util.py:397, in _get_result_paths_thunk(_fun, _store, *args, **kwargs)
#     395 @transformation_with_aux2
#     396 def _get_result_paths_thunk(_fun: Callable, _store: Store, *args, **kwargs):
# --> 397   ans = _fun(*args, **kwargs)
#     398   result_paths = tuple(f"result{_clean_keystr_arg_names(path)}" for path, _ in generate_key_paths(ans))
#     399   if _store:
#     400     # In some instances a lu.WrappedFun is called multiple times, e.g.,
#     401     # the bwd function in a custom_vjp
#
# File ~/venvs/jaxoenv/lib/python3.11/site-packages/numpyro/infer/util.py:325, in potential_energy(model, model_args, model_kwargs, params, enum)
#     321 substituted_model = substitute(
#     322     model, substitute_fn=partial(_unconstrain_reparam, params)
#     323 )
#     324 # no param is needed for log_density computation because we already substitute
# --> 325 log_joint, model_trace = log_density_(
#     326     substituted_model, model_args, model_kwargs, {}
#     327 )
#     328 return -log_joint
#
# File ~/venvs/jaxoenv/lib/python3.11/site-packages/numpyro/infer/util.py:121, in log_density(model, model_args, model_kwargs, params)
#     110 def log_density(model, model_args: tuple, model_kwargs: dict, params: dict):
#     111     """
#     112     (EXPERIMENTAL INTERFACE) Computes log of joint density for the model given latent
#     113     values ``params``.
#    (...)    119     :return: Log of joint density and a corresponding model trace.
#     120     """
# --> 121     log_joint, model_trace = compute_log_probs(model, model_args, model_kwargs, params)
#     122     # We need to start with 0.0 instead of 0 because log_joint may be empty or only
#     123     # contain integers, but log_density must be a floating point value to be
#     124     # differentiable by jax.
#     125     return sum(log_joint.values(), start=0.0), model_trace
#
# File ~/venvs/jaxoenv/lib/python3.11/site-packages/numpyro/infer/util.py:79, in compute_log_probs(model, model_args, model_kwargs, params, sum_log_prob)
#      66 """
#      67 (EXPERIMENTAL INTERFACE) Computes log of density for each site of the model given
#      68 latent values ``params``.
#    (...)     76     trace.
#      77 """
#      78 model = substitute(model, data=params)
# ---> 79 model_trace = trace(model).get_trace(*model_args, **model_kwargs)
#      80 log_joint = {}
#      81 for site in model_trace.values():
#
# File ~/venvs/jaxoenv/lib/python3.11/site-packages/numpyro/handlers.py:193, in trace.get_trace(self, *args, **kwargs)
#     185 def get_trace(self, *args, **kwargs) -> TraceT:
#     186     """
#     187     Run the wrapped callable and return the recorded trace.
#     188
#    (...)    191     :return: `OrderedDict` containing the execution trace.
#     192     """
# --> 193     self(*args, **kwargs)
#     194     return self.trace
#
# File ~/venvs/jaxoenv/lib/python3.11/site-packages/numpyro/primitives.py:119, in Messenger.__call__(self, *args, **kwargs)
#     117     return self
#     118 with self:
# --> 119     return self.fn(*args, **kwargs)
#
# File ~/venvs/jaxoenv/lib/python3.11/site-packages/numpyro/primitives.py:119, in Messenger.__call__(self, *args, **kwargs)
#     117     return self
#     118 with self:
# --> 119     return self.fn(*args, **kwargs)
#
#     [... skipping similar frames: Messenger.__call__ at line 119 (3 times)]
#
# File ~/venvs/jaxoenv/lib/python3.11/site-packages/numpyro/primitives.py:119, in Messenger.__call__(self, *args, **kwargs)
#     117     return self
#     118 with self:
# --> 119     return self.fn(*args, **kwargs)
#
# Cell In[15], line 26, in mcmc.<locals>.MCMC_model(time, yerr, y)
#      23 u2 = numpyro.sample("u2", numpyro.distributions.Normal(uu[1], 0.2))
#      25 # The orbit and light curve
# ---> 26 y_pred = light_curve_model(time, lamb, r, T_planet_prior, T_star_prior, P, R_star_prior, M_star, time_transit, (u1, u2))
#      28 # Let's track the light curve
#      29 numpyro.deterministic("light_curve", y_pred)
#
# Cell In[4], line 26, in light_curve_model(time, lamb, R, T_planet, T_star, P, R_star, M_star, time_transit, uu)
#      24 flux_star = planck(lamb*1e-6, jnp.mean(T_star))
#      25 flux_planet = planck(lamb*1e-6, jnp.mean(T_planet))
# ---> 26 pc = light_curve(system, flux_planet, flux_star)(time)[:,1] + light_curve(system, flux_planet, flux_star)(time)[:,0]
#      27 #pc = pc/np.max(pc)
#      28 return pc
#
# File ~/venvs/jaxoenv/lib/python3.11/site-packages/jax/_src/numpy/vectorize.py:347, in vectorize.<locals>.wrapped(*args, **kwargs)
#     345   else:
#     346     vectorized_func = api.vmap(vectorized_func, in_axes)
# --> 347 result = vectorized_func(*squeezed_args)
#     349 if not dims_to_expand:
#     350   return result
#
#     [... skipping hidden 1 frame]
#
# File ~/venvs/jaxoenv/lib/python3.11/site-packages/jax/_src/api.py:1112, in vmap.<locals>.vmap_f(*args, **kwargs)
#    1109 try:
#    1110   axis_data = batching.AxisData(axis_name, axis_size_, spmd_axis_name,
#    1111                                 explicit_mesh_axis)
# -> 1112   out_flat = batching.batch(
#    1113       flat_fun, axis_data, in_axes_flat,
#    1114       lambda: flatten_axes("vmap out_axes", out_tree(), out_axes)
#    1115   ).call_wrapped(*args_flat)
#    1116 except batching.SpecMatchError as e:
#    1117   out_axes_flat = flatten_axes("vmap out_axes", out_tree(), out_axes)
#
# File ~/venvs/jaxoenv/lib/python3.11/site-packages/jax/_src/linear_util.py:212, in WrappedFun.call_wrapped(self, *args, **kwargs)
#     210 def call_wrapped(self, *args, **kwargs):
#     211   """Calls the transformed function"""
# --> 212   return self.f_transformed(*args, **kwargs)
#
# File ~/venvs/jaxoenv/lib/python3.11/site-packages/jax/_src/interpreters/batching.py:644, in _batch_outer(f, axis_data, in_dims, *in_vals)
#     642 tag = TraceTag()
#     643 with source_info_util.transform_name_stack('vmap'):
# --> 644   outs, trace = f(tag, in_dims, *in_vals)
#     645 with core.ensure_no_leaks(trace): del trace
#     646 return outs
#
# File ~/venvs/jaxoenv/lib/python3.11/site-packages/jax/_src/interpreters/batching.py:660, in _batch_inner(f, axis_data, out_dim_dests, tag, in_dims, *in_vals)
#     656   in_tracers = map(partial(to_elt, trace, idx), in_vals, in_dims)
#     657 with (core.set_current_trace(trace),
#     658       core.extend_axis_env_nd([(axis_data.name, axis_data.size)]),
#     659       core.add_spmd_axis_names(axis_data.spmd_name)):
# --> 660   outs = f(*in_tracers)
#     661   out_dim_dests = out_dim_dests() if callable(out_dim_dests) else out_dim_dests
#     662   out_vals = map(partial(from_elt, trace, axis_data.size, axis_data.explicit_mesh_axis),
#     663                  range(len(outs)), outs, out_dim_dests)
#
# File ~/venvs/jaxoenv/lib/python3.11/site-packages/jax/_src/interpreters/batching.py:342, in flatten_fun_for_vmap(f, store, in_tree, *args_flat)
#     338 @lu.transformation_with_aux2
#     339 def flatten_fun_for_vmap(f: Callable,
#     340                          store: lu.Store, in_tree: PyTreeDef, *args_flat):
#     341   py_args, py_kwargs = tree_unflatten(in_tree, args_flat)
# --> 342   ans = f(*py_args, **py_kwargs)
#     343   ans, out_tree = tree_flatten(ans, is_leaf=is_vmappable)
#     344   store.store(out_tree)
#
# File ~/venvs/jaxoenv/lib/python3.11/site-packages/jax/_src/linear_util.py:397, in _get_result_paths_thunk(_fun, _store, *args, **kwargs)
#     395 @transformation_with_aux2
#     396 def _get_result_paths_thunk(_fun: Callable, _store: Store, *args, **kwargs):
# --> 397   ans = _fun(*args, **kwargs)
#     398   result_paths = tuple(f"result{_clean_keystr_arg_names(path)}" for path, _ in generate_key_paths(ans))
#     399   if _store:
#     400     # In some instances a lu.WrappedFun is called multiple times, e.g.,
#     401     # the bwd function in a custom_vjp
#
# File ~/venvs/jaxoenv/lib/python3.11/site-packages/jax/_src/numpy/vectorize.py:144, in _check_output_dims.<locals>.wrapped(*args)
#     143 def wrapped(*args):
# --> 144   out = func(*args)
#     145   out_shapes = map(np.shape, out if isinstance(out, tuple) else [out])
#     147   output_core_dims = expected_output_core_dims
#
# Cell In[2], line 170, in system_observable.<locals>.observable_fun.<locals>.observable_impl(time)
#     168 theta = system.central_surface.rotational_phase(time)
#     169 central_radius = system.central.radius
# --> 170 central_phase_curve = _surface_observable(
#     171     system.central_surface, theta=theta
#     172 )
#     173 if len(system.bodies) > 0:
#     174     xos, yos, zos = system.relative_position(time)
#
# Cell In[2], line 118, in surface_light_curve(surface, r, x, y, z, theta, order, higher_precision)
#     116 else:
#     117     u = jnp.array([1, *surface.u])
# --> 118     p_u = Pijk.from_dense(u @ U(surface.udeg), degree=surface.udeg)
#     120 # surface map * limb darkening map
#     121 if higher_precision:
#
# File ~/venvs/jaxoenv/lib/python3.11/site-packages/jaxoplanet/starry/core/polynomials.py:115, in Pijk.from_dense(cls, x, degree)
#     113 data = defaultdict(float)
#     114 for i in range(len(x)):
# --> 115     data[Pijk.n2ijk(i)] = x[i]
#     117 return cls(data, degree=degree)
#
# File ~/venvs/jaxoenv/lib/python3.11/site-packages/jax/_src/numpy/array_methods.py:1122, in _forward_operator_to_aval.<locals>.op(self, *args)
#    1121 def op(self, *args):
# -> 1122   return getattr(self.aval, f"_{name}")(self, *args)
#
# File ~/venvs/jaxoenv/lib/python3.11/site-packages/jax/_src/numpy/array_methods.py:659, in _getitem(self, item)
#     658 def _getitem(self, item):
# --> 659   return indexing.rewriting_take(self, item)
#
# File ~/venvs/jaxoenv/lib/python3.11/site-packages/jax/_src/numpy/indexing.py:639, in rewriting_take(arr, idx, indices_are_sorted, unique_indices, mode, fill_value, normalize_indices, out_sharding)
#     628 def rewriting_take(arr, idx, indices_are_sorted=False, unique_indices=False,
#     629                    mode=None, fill_value=None, normalize_indices=True,
#     630                    out_sharding=None):
#    (...)    636   # in the simplest cases: i.e. non-dynamic arrays indexed with integers and slices.
#     637   # TODO(jakevdp): lower to slice even when normalize_indices is False
#     638   if normalize_indices:
# --> 639     result = _attempt_rewriting_take_via_slice(arr, idx, mode, out_sharding)
#     640     if result is not None:
#     641       return result
#
# File ~/venvs/jaxoenv/lib/python3.11/site-packages/jax/_src/numpy/indexing.py:602, in _attempt_rewriting_take_via_slice(arr, idx, mode, out_sharding)
#     600   int_start_indices = [int(i) for i in start_indices]  # type: ignore
#     601   int_limit_indices = [i + s for i, s in zip(int_start_indices, slice_sizes)]
# --> 602   arr = slicing.slice(
#     603       arr, start_indices=int_start_indices, limit_indices=int_limit_indices)
#     604 else:
#     605   # We must be careful with dtypes because dynamic_slice requires all
#     606   # start indices to have matching types.
#     607   if len(start_indices) > 1:
#
# File ~/venvs/jaxoenv/lib/python3.11/site-packages/jax/_src/lax/slicing.py:110, in slice(operand, start_indices, limit_indices, strides)
#      59 def slice(operand: ArrayLike, start_indices: Sequence[int],
#      60           limit_indices: Sequence[int],
#      61           strides: Sequence[int] | None = None) -> Array:
#      62   """Wraps XLA's `Slice
#      63   <https://www.openxla.org/xla/operation_semantics#slice>`_
#      64   operator.
#    (...)    108     - :func:`jax.lax.dynamic_slice`
#     109   """
# --> 110   return slice_p.bind(operand, start_indices=tuple(start_indices),
#     111                       limit_indices=tuple(limit_indices),
#     112                       strides=None if strides is None else tuple(strides))
#
# File ~/venvs/jaxoenv/lib/python3.11/site-packages/jax/_src/core.py:612, in Primitive.bind(self, *args, **params)
#     610 def bind(self, *args, **params):
#     611   args = args if self.skip_canonicalization else map(canonicalize_value, args)
# --> 612   return self._true_bind(*args, **params)
#
# File ~/venvs/jaxoenv/lib/python3.11/site-packages/jax/_src/core.py:628, in Primitive._true_bind(self, *args, **params)
#     626 trace_ctx.set_trace(eval_trace)
#     627 try:
# --> 628   return self.bind_with_trace(prev_trace, args, params)
#     629 finally:
#     630   trace_ctx.set_trace(prev_trace)
#
# File ~/venvs/jaxoenv/lib/python3.11/site-packages/jax/_src/core.py:638, in Primitive.bind_with_trace(self, trace, args, params)
#     635   with set_current_trace(trace):
#     636     return self.to_lojax(*args, **params)  # type: ignore
# --> 638 return trace.process_primitive(self, args, params)
#
# File ~/venvs/jaxoenv/lib/python3.11/site-packages/jax/_src/interpreters/batching.py:528, in BatchTrace.process_primitive(self, p, tracers, params)
#     524       val_out, dim_out = fancy_primitive_batchers[p](
#     525           self.axis_data, vals_in, dims_in, **params)
#     526 elif args_not_mapped:
#     527   # no-op shortcut
# --> 528   return p.bind_with_trace(self.parent_trace, vals_in, params)
#     529 elif p in primitive_batchers:
#     530   with core.set_current_trace(self.parent_trace):
#
# File ~/venvs/jaxoenv/lib/python3.11/site-packages/jax/_src/core.py:638, in Primitive.bind_with_trace(self, trace, args, params)
#     635   with set_current_trace(trace):
#     636     return self.to_lojax(*args, **params)  # type: ignore
# --> 638 return trace.process_primitive(self, args, params)
#
# File ~/venvs/jaxoenv/lib/python3.11/site-packages/jax/_src/interpreters/ad.py:891, in LinearizeTrace.process_primitive(self, primitive, args, params)
#     889 lin = primitive_linearizations.get(primitive, fallback)
#     890 with core.set_current_trace(self.parent_trace):
# --> 891   primal_out, tangent_nzs_out, residuals, linearized = lin(
#     892       tangent_nzs, *primals_in, **params)
#     893 with (core.set_current_trace(self.tangent_trace),
#     894       source_info_util.set_name_stack(self._name_stack_suffix())):
#     895   tangent_out = linearized(residuals, *tangents_in)
#
# File ~/venvs/jaxoenv/lib/python3.11/site-packages/jax/_src/interpreters/ad.py:1052, in fallback_linearize_rule(_prim, _nonzeros, *primals, **params)
#    1050   raise NotImplementedError(msg)
#    1051 debug_jvp = debug_info("linearize_prim_jvp", jvp, primals, params)
# -> 1052 return linearize_from_jvp(lu.wrap_init(jvp, debug_info=debug_jvp),
#    1053                           _prim.multiple_results, _nonzeros, False, False,
#    1054                           primals, params)
#
# File ~/venvs/jaxoenv/lib/python3.11/site-packages/jax/_src/interpreters/ad.py:1086, in linearize_from_jvp(jvp, multiple_results, nonzeros, user_facing_symbolic_zeros, instantiate_input_zeros, primals, params)
#    1083 with core.set_current_trace(trace):
#    1084   tangent_args = [trace.new_arg(pe.PartialVal.unknown(a)) if nz else make_zero(a)
#    1085                   for a, nz in zip(tangent_avals, nonzeros)]
# -> 1086   out_primals, out_tangents = jvp.call_wrapped(
#    1087       tuple(primals), tuple(tangent_args), **params)
#    1089 if not multiple_results:
#    1090   out_primals = [out_primals]
#
# File ~/venvs/jaxoenv/lib/python3.11/site-packages/jax/_src/linear_util.py:212, in WrappedFun.call_wrapped(self, *args, **kwargs)
#     210 def call_wrapped(self, *args, **kwargs):
#     211   """Calls the transformed function"""
# --> 212   return self.f_transformed(*args, **kwargs)
#
# File ~/venvs/jaxoenv/lib/python3.11/site-packages/jax/_src/linear_util.py:397, in _get_result_paths_thunk(_fun, _store, *args, **kwargs)
#     395 @transformation_with_aux2
#     396 def _get_result_paths_thunk(_fun: Callable, _store: Store, *args, **kwargs):
# --> 397   ans = _fun(*args, **kwargs)
#     398   result_paths = tuple(f"result{_clean_keystr_arg_names(path)}" for path, _ in generate_key_paths(ans))
#     399   if _store:
#     400     # In some instances a lu.WrappedFun is called multiple times, e.g.,
#     401     # the bwd function in a custom_vjp
#
# File ~/venvs/jaxoenv/lib/python3.11/site-packages/jax/_src/interpreters/ad.py:1173, in linear_jvp(primitive, primals, tangents, **params)
#    1172 def linear_jvp(primitive, primals, tangents, **params):
# -> 1173   val_out = primitive.bind(*primals, **params)
#    1174   if all(type(tangent) is Zero for tangent in tangents):
#    1175     if primitive.multiple_results:
#
# File ~/venvs/jaxoenv/lib/python3.11/site-packages/jax/_src/core.py:612, in Primitive.bind(self, *args, **params)
#     610 def bind(self, *args, **params):
#     611   args = args if self.skip_canonicalization else map(canonicalize_value, args)
# --> 612   return self._true_bind(*args, **params)
#
# File ~/venvs/jaxoenv/lib/python3.11/site-packages/jax/_src/core.py:614, in Primitive._true_bind(self, *args, **params)
#     611   args = args if self.skip_canonicalization else map(canonicalize_value, args)
#     612   return self._true_bind(*args, **params)
# --> 614 def _true_bind(self, *args, **params):
#     615   for arg in args:
#     616     if isinstance(arg, Tracer) and not arg._trace.is_valid():
#
# KeyboardInterrupt:
# Canvas(toolbar=Toolbar(toolitems=[('Home', 'Reset original view', 'home', 'home'), ('Back', 'Back to previous …

# %%
radii = [np.float64(0.011914195169255754), np.float64(0.011796041281380867), np.float64(0.011691259589179617), np.float64(0.011898263112785608), np.float64(0.011835223562172197)]
radii_plus = [np.float64(0.0001822338110646811), np.float64(9.667810361068015e-05), np.float64(0.0001423261797635668), np.float64(0.00019669422060385536), np.float64(0.00019360349868962137)]
radii_minus = [np.float64(0.00016810548354498876), np.float64(8.708184510037957e-05), np.float64(0.0001500186657301672), np.float64(0.00019883316569517182), np.float64(0.00018110870101775006)]
Temps = [np.float64(1044.5190585111627), np.float64(1055.6954729682202), np.float64(1058.0927917878525), np.float64(1037.3815062163017), np.float64(970.1929118824233)]
Temps_plus = [np.float64(189.97345054412312), np.float64(109.20526779618831), np.float64(50.0002065899414), np.float64(37.68081802464553), np.float64(27.011632602612735)]
Temps_minus = [np.float64(205.30095043547476), np.float64(157.83733685518519), np.float64(48.4122201942763), np.float64(35.023239885232215), np.float64(22.449475656927007)]
Temps_star = [np.float64(3036.834013017712), np.float64(3036.7930858115415), np.float64(3036.6045201111997), np.float64(3036.748008227609), np.float64(3036.930845055757)]
Temps_star_plus = [np.float64(8.89487518969645), np.float64(9.786958942350793), np.float64(8.978435972698662), np.float64(9.307017967107186), np.float64(9.166163788814174)]
Temps_star_minus = [np.float64(9.981885711566974), np.float64(10.02696506940265), np.float64(9.724656769962166), np.float64(9.932705207935214), np.float64(9.14251390065283)]
u1 = [np.float64(0.4688509901347141), np.float64(0.4396391912141232), np.float64(0.4925688525859919), np.float64(0.4571148949593108), np.float64(0.4459885907077925)]
u1_plus = [np.float64(0.12077856391508146), np.float64(0.09082760811288271), np.float64(0.10596342095138045), np.float64(0.12036137838156258), np.float64(0.13413841946401683)]
u1_minus = [np.float64(0.12912837052067616), np.float64(0.09551490404125274), np.float64(0.12106067252512992), np.float64(0.13754742486219962), np.float64(0.12636392346890418)]
u2 = [np.float64(0.11321556350332176), np.float64(0.15233183479349993), np.float64(0.15403862582969474), np.float64(0.07762102026640903), np.float64(0.06541745664451129)]
u2_plus = [np.float64(0.1685010559255851), np.float64(0.14221688874115634), np.float64(0.1550661943163808), np.float64(0.17642476266031143), np.float64(0.16736816004693195)]
u2_minus = [np.float64(0.1668266986141934), np.float64(0.14112432132909267), np.float64(0.15958422615713844), np.float64(0.1794550705615212), np.float64(0.16979806147638182)]

# %%
print(instru)
# Out:
# [b'FGS1', b'FGS2', b'NIRSpec', b'AIRS-Ch0-1', b'AIRS-Ch0-2', b'AIRS-CH1']

# %%
for i, inst in enumerate(instru) : 
    print(i)
    if i != 0:
        print(inst)
        time = df2['datasets'][inst]['lc']['time'] - 2458828.93
        pc = df2['datasets'][inst]['lc']['model']
        plt.figure()
        plt.errorbar(time, df2['datasets'][inst]['lc']['ariel'], yerr=df2['datasets'][inst]['lc']['flux_error'], c=(1, 1, 0.2), fmt='.', label='data')
        plt.plot(time, light_curve_model(time, list(wvl)[i], R, T_planet, T_star, P, R_star, M_star, time_transit, uu), label='our model', zorder=10)
        plt.plot(time, light_curve_model(time, list(wvl)[i], radii[i-1], Temps[i-1], Temps_star[i-1], P, R_star, M_star, time_transit, (u1[i-1], u2[i-1])), "--C0", label="MCMC result", zorder=5)
        plt.plot(time, pc, 'k', label='origin data', zorder=3)
        plt.title(rf'Phase curve at $\lambda$ = {list(wvl)[i]} $\mu$m with {str(inst)[2:-1]}', fontsize=16)
        plt.legend(fontsize=12)
        plt.xlabel(r'BJD$_{TDB}$ - 2,458,829 [d]', fontsize=14)
        plt.ylabel(r'$(F_p + F_{\bigstar})/F_{\bigstar}$', fontsize=14)
        plt.savefig(f"mcmc_{str(inst)[2:-1]}.svg")
        plt.show()
# Out:
# 0
# 1
# b'FGS2'
# Canvas(toolbar=Toolbar(toolitems=[('Home', 'Reset original view', 'home', 'home'), ('Back', 'Back to previous …
# 2
# b'NIRSpec'
# Canvas(toolbar=Toolbar(toolitems=[('Home', 'Reset original view', 'home', 'home'), ('Back', 'Back to previous …
# 3
# b'AIRS-Ch0-1'
# Canvas(toolbar=Toolbar(toolitems=[('Home', 'Reset original view', 'home', 'home'), ('Back', 'Back to previous …
# 4
# b'AIRS-Ch0-2'
# Canvas(toolbar=Toolbar(toolitems=[('Home', 'Reset original view', 'home', 'home'), ('Back', 'Back to previous …
# 5
# b'AIRS-CH1'
# Canvas(toolbar=Toolbar(toolitems=[('Home', 'Reset original view', 'home', 'home'), ('Back', 'Back to previous …

# %%
r_yerr = np.vstack((radii_minus, radii_plus))

plt.figure()
plt.plot(list(wvl)[1:], R*(const.R_sun/const.R_earth)*np.ones(len(list(wvl)[1:])), label='true value')
plt.errorbar(list(wvl)[1:], radii*const.R_sun/const.R_earth, r_yerr*const.R_sun/const.R_earth, fmt='-o')
for i, (x_val, y_val) in enumerate(zip(list(wvl)[1:], radii*const.R_sun/const.R_earth)):
    plt.annotate(f'{str(instru[i+1])[2:-1]}',
                 (x_val, y_val),
                 textcoords="offset points",  # how to position the text
                 xytext=(0, 10),              # distance from the point
                 ha='center')                 # horizontal alignment
#plt.plot(wvl, radii*const.R_sun/const.R_earth)
#plt.fill_between(wvl, (np.array(radii) - np.array(radii_minus))*const.R_sun/const.R_earth, (np.array(radii) + np.array(radii_plus))*const.R_sun/const.R_earth, alpha=0.2)
plt.xlabel(r'$\lambda$ ($\mu$m)', fontsize=14)
plt.ylabel(r'R$_p$ (R$_\oplus$)', fontsize=14)
plt.legend(fontsize=12)
plt.title('Radius of LHS 3844 b vs wavelength', fontsize=14)
plt.savefig('radii.svg')
plt.show()
# Out:
# Canvas(toolbar=Toolbar(toolitems=[('Home', 'Reset original view', 'home', 'home'), ('Back', 'Back to previous …

# %%
from Transits import transit_impact_parameter
import astropy.units as u
import astropy.constants as const

b = 0.186
mu_0 = np.sqrt(1-b**2)
theta = np.linspace(0, np.pi/2, 100)
mu = np.cos(theta)
factor = []
factor_minus = []
factor_plus = []
factor_init = []
star_fluxes = []
star_fluxes_minus = []
star_fluxes_plus = []

def I(I1, mu, u1, u2):
        return I1 * (1 - u1*(1-mu) - u2*(1-mu)**2)

for i in range(5):
    star_fluxes.append(planck(list(wvl)[i+1]*1e-6, Temps_star[i]))
    star_fluxes_minus.append(planck(list(wvl)[i+1]*1e-6, Temps_star_minus[i]))
    star_fluxes_plus.append(planck(list(wvl)[i+1]*1e-6, Temps_star_plus[i]))
    I1 = star_fluxes[i]/(2*np.pi*(0.5 - u1[i]/6 - u2[i]/12))
    I1_minus = star_fluxes_minus[i]/(2*np.pi*(0.5 - u1_minus[i]/6 - u2_minus[i]/12))
    I1_plus = star_fluxes_plus[i]/(2*np.pi*(0.5 - u1_plus[i]/6 - u2_plus[i]/12))
    I1_init = star_fluxes[i]/(2*np.pi*(0.5 - uu[0]/6 - uu[1]/12))
    I_avg = I1 * (1 - u1[i]/3. - u2[i]/6.)
    I_avg_minus = I1_minus * (1 - u1_minus[i]/3. - u2_minus[i]/6.)
    I_avg_plus = I1_plus * (1 - u1_plus[i]/3. - u2_plus[i]/6.)
    I_avg_init = I1_init * (1 - uu[0]/3. - uu[1]/6.)
    factor.append(I(I1, mu_0, u1[i], u2[i])/I_avg)
    factor_minus.append(I(I1_minus, mu_0, u1_minus[i], u2_minus[i])/I_avg_minus)
    factor_plus.append(I(I1_plus, mu_0, u1_plus[i], u2_plus[i])/I_avg_plus)
    factor_init.append(I(I1_init, mu_0, uu[0], uu[1])/I_avg_init)
print(factor)
print(factor_minus)
print(factor_plus)
print(factor_init)

"""I = []
I_minus = []
I_plus = []

for i in range(5):
    I.append(1 - u1[i]*(1-mu_0) - u2[i]*(1-mu_0)**2)
    I_minus.append(1 - u1_minus[i]*(1-mu_0) - u2_minus[i]*(1-mu_0)**2)
    I_plus.append(1 - u1_plus[i]*(1-mu_0) - u2_plus[i]*(1-mu_0)**2)

print(I)
print(I_minus)
print(I_plus)"""
# Out:
# [Array(1.20238525, dtype=float64), Array(1.19831395, dtype=float64), Array(1.22369093, dtype=float64), Array(1.18846251, dtype=float64), Array(1.18057717, dtype=float64)]
# [Array(nan, dtype=float64), Array(nan, dtype=float64), Array(1.06943878, dtype=float64), Array(1.07931198, dtype=float64), Array(1.07332803, dtype=float64)]
# [Array(nan, dtype=float64), Array(nan, dtype=float64), Array(1.06313061, dtype=float64), Array(1.07240441, dtype=float64), Array(1.07571313, dtype=float64)]
# [Array(1.17877088, dtype=float64), Array(1.17877088, dtype=float64), Array(1.17877088, dtype=float64), Array(1.17877088, dtype=float64), Array(1.17877088, dtype=float64)]
# 'I = []\nI_minus = []\nI_plus = []\n\nfor i in range(5):\n    I.append(1 - u1[i]*(1-mu_0) - u2[i]*(1-mu_0)**2)\n    I_minus.append(1 - u1_minus[i]*(1-mu_0) - u2_minus[i]*(1-mu_0)**2)\n    I_plus.append(1 - u1_plus[i]*(1-mu_0) - u2_plus[i]*(1-mu_0)**2)\n\nprint(I)\nprint(I_minus)\nprint(I_plus)'

# %%
transit_depth = ((np.array(radii)/R_star)**2)*np.array(factor)
transit_depth_plus = 2*np.array(radii)*np.array(radii_plus)/(R_star)**2
transit_depth_minus = 2*np.array(radii)*np.array(radii_minus)/(R_star)**2
transit_depth_plus_asy = ((( (np.array(radii)+np.array(radii_plus)) /R_star )**2)*(np.array(factor)+np.array(factor_plus))) - ((np.array(radii)/R_star)**2)*(np.array(factor))
transit_depth_minus_asy =  ((np.array(radii)/R_star)**2)*(np.array(factor)) - ((((np.array(radii)-np.array(radii_minus))/R_star)**2)*(np.array(factor)-np.array(factor_minus)))

transit_yerr = np.vstack((transit_depth_minus, transit_depth_plus))
transit_yerr_asy = np.vstack((transit_depth_minus_asy, transit_depth_plus_asy))

plt.figure()
plt.plot(list(wvl)[1:], ((R/R_star)**2)*np.array(factor_init)*1e6, label='initial value')
plt.errorbar(list(wvl)[1:], transit_depth*1e6, transit_yerr_asy*1e6, fmt='-o')
plt.plot(list(wvl)[1:], 0*np.ones(5), 'k--')
for i, (x_val, y_val) in enumerate(zip(list(wvl)[1:], transit_depth*1e6)):
    plt.annotate(f'{str(instru[i+1])[2:-1]}',
                 (x_val, y_val),
                 textcoords="offset points",  # how to position the text
                 xytext=(0, 10),              # distance from the point
                 ha='center')                 # horizontal alignment
#plt.errorbar(wvl, transit_depth*1e6, transit_yerr_asy*1e6, fmt='-o', label='asymmetric error')
#plt.plot(wvl, (((np.array(radii)+np.array(radii_plus))/R_star)**2)*1e6)
plt.xlabel(r'$\lambda$ ($\mu$m)', fontsize=14)
plt.ylabel(r'Transit depth (ppm)', fontsize=14)
plt.title(r'Transit depth = (R$_p$/R$_\bigstar$)$^2$ vs wavelength', fontsize=14)
plt.legend(fontsize=12)
plt.savefig('transit_depth.svg')
plt.show()
# Out:
# Canvas(toolbar=Toolbar(toolitems=[('Home', 'Reset original view', 'home', 'home'), ('Back', 'Back to previous …

# %%
planet_fluxes = []
planet_fluxes_plus = []
planet_fluxes_minus = []
star_fluxes = []
eclipse_depths = []
eclipse_depths_plus = []
eclipse_depths_minus = []
planet_fluxes_minus_symm = []
planet_fluxes_plus_symm = []
eclipse_depths_minus_symm = []
eclipse_depths_plus_symm = []

def dB_dT(lam, T):
    x = h*c/(lam*kB*T)
    return (2*h*c**2/lam**5) * (x*np.exp(x)) / (T*(np.exp(x)-1)**2)

for i in range(len(wvl)):
    T50 = Temps[i]
    T16 = Temps[i] - Temps_minus[i]
    T84 = Temps[i] + Temps_plus[i]
    B50 = planck(list(wvl)[i]*1e-6, T50)
    B16 = planck(list(wvl)[i]*1e-6, T16)
    B84 = planck(list(wvl)[i]*1e-6, T84)
    R50 = radii[i]
    R16 = radii[i] - radii_minus[i]
    R84 = radii[i] + radii_plus[i]
    planet_fluxes.append(B50)
    planet_fluxes_minus_symm.append(dB_dT(list(wvl)[i]*1e-6, Temps[i])*Temps_minus[i])
    planet_fluxes_plus_symm.append(dB_dT(list(wvl)[i]*1e-6, Temps[i])*Temps_plus[i])
    planet_fluxes_minus.append(B50 - B16)
    planet_fluxes_plus.append(B84 - B50)
    star_fluxes.append(planck(list(wvl)[i]*1e-6, T_star))
    depth50 = (B50/star_fluxes[i])*(R50/R_star)**2
    depth16 = (B16/star_fluxes[i])*(R16/R_star)**2
    depth84 = (B84/star_fluxes[i])*(R84/R_star)**2
    eclipse_depths.append(depth50)
    cst = 1/(star_fluxes[i]*R_star**2)
    eclipse_depths_minus_symm.append(np.sqrt((cst*(radii[i]**2)*planet_fluxes_minus_symm[i])**2 + (2*cst*planet_fluxes[i]*radii[i]*radii_minus[i])**2))
    eclipse_depths_plus_symm.append(np.sqrt((cst*(radii[i]**2)*planet_fluxes_plus_symm[i])**2 + (2*cst*planet_fluxes[i]*radii[i]*radii_plus[i])**2))
    eclipse_depths_minus.append(depth50 - depth16)
    eclipse_depths_plus.append(depth84 - depth50)

print(wvl)
print(instru)
print(eclipse_depths)
print(eclipse_depths_minus)
print(eclipse_depths_plus)
print(planet_fluxes_minus)
print(planet_fluxes_plus)
depth_yerr = np.vstack((eclipse_depths_minus, eclipse_depths_plus))
depth_yerr_symm = np.vstack((eclipse_depths_minus_symm, eclipse_depths_plus_symm))
#depth_yerr_2 = np.vstack((eclipse_minus_2, eclipse_plus_2))

wvl_array = np.arange(0.6, 6, 0.1)
plt.figure()
#plt.errorbar(wvl, np.array(eclipse_depths)*1e6, np.array(depth_yerr)*1e6, fmt='-o', label='asymmetric error')
#plt.errorbar(wvl, np.array(eclipse_depths)*1e6, np.array(depth_yerr_symm)*1e6, fmt='--o', label='symmetric error')
#plt.errorbar(wvl, np.array(eclipse_depths_2)*1e6, np.array(depth_yerr_2)*1e6, fmt='-o', label='from MCMC')
plt.plot(wvl, np.array(eclipse_depths)*1e6, '-o')
plt.fill_between(wvl, (np.array(eclipse_depths) - np.array(eclipse_depths_minus_symm)/np.sqrt(3))*1e6, (np.array(eclipse_depths) + np.array(eclipse_depths_plus_symm)/np.sqrt(3))*1e6, alpha=0.2, label='symmetric error')
plt.fill_between(wvl, (np.array(eclipse_depths) - np.array(eclipse_depths_minus)/np.sqrt(3))*1e6, (np.array(eclipse_depths) + np.array(eclipse_depths_plus)/np.sqrt(3))*1e6, alpha=0.2, label='asymmetric error')
plt.plot(wvl_array, ((planck(wvl_array*1e-6, T_planet)/planck(wvl_array*1e-6, T_star))*(R/R_star)**2)*1e6, label='with true values')
plt.plot(wvl_array, 0*np.ones(len(wvl_array)), 'k--')
plt.errorbar(4.5, 380, yerr=40, fmt='o',c='k', label='Spitzer data point Kreidberg 2019')
for i, (x_val, y_val) in enumerate(zip(wvl, np.array(eclipse_depths)*1e6)):
    plt.annotate(f'{str(instru[i])[2:-1]}',
                 (x_val, y_val),
                 textcoords="offset points",  # how to position the text
                 xytext=(0, 10),              # distance from the point
                 ha='center')                 # horizontal alignment
plt.xlabel(r'$\lambda$ ($\mu$m)', fontsize=14)
plt.ylabel(r'Eclipse depth (ppm)', fontsize=14)
plt.title(r'Eclipse depth B(T$_p$)R$_p^2$/B(T$_\bigstar$)R$_\bigstar^2$', fontsize=14)
plt.legend(fontsize=12)
plt.savefig('eclipse_depth.svg')
plt.show()

"""plt.figure()
#plt.errorbar(wvl, np.array(eclipse_depths_2)*1e6, np.array(depth_yerr_2)*1e6, fmt='-o', label='from MCMC')
plt.plot(wvl_array, ((planck(wvl_array*1e-6, T_planet)/planck(wvl_array*1e-6, T_star))*(R/R_star)**2)*1e6, label='with true values')
plt.xlabel(r'$\lambda$ ($\mu$m)')
plt.ylabel(r'Eclipse depth (ppm)')
#plt.ylim(0, 1)
plt.legend()
plt.show()"""

plt.figure()
plt.errorbar(wvl, np.array(eclipse_depths)*1e6, (np.array(depth_yerr_symm)/np.sqrt(8))*1e6, fmt='-o')
plt.fill_between(wvl, (np.array(eclipse_depths) - np.array(eclipse_depths_minus_symm)/np.sqrt(8))*1e6, (np.array(eclipse_depths) + np.array(eclipse_depths_plus_symm)/np.sqrt(8))*1e6, alpha=0.2, label='symmetric error')
plt.fill_between(wvl, (np.array(eclipse_depths) - np.array(eclipse_depths_minus)/np.sqrt(8))*1e6, (np.array(eclipse_depths) + np.array(eclipse_depths_plus)/np.sqrt(8))*1e6, alpha=0.2, label='asymmetric error')
plt.plot(wvl_array, ((planck(wvl_array*1e-6, T_planet)/planck(wvl_array*1e-6, T_star))*(R/R_star)**2)*1e6, label='with true values')
plt.plot(wvl_array, 0*np.ones(len(wvl_array)), 'k--')
for i, (x_val, y_val) in enumerate(zip(wvl, np.array(eclipse_depths)*1e6)):
    plt.annotate(f'{str(instru[i])[2:-1]}',
                 (x_val, 1),
                 textcoords="offset points",  # how to position the text
                 xytext=(0, 10),              # distance from the point
                 ha='center')                 # horizontal alignment
plt.xlabel(r'$\lambda$ ($\mu$m)', fontsize=14)
plt.ylabel(r'Eclipse depth (ppm)', fontsize=14)
plt.title(r'Eclipse depth B(T$_p$)R$_p^2$/B(T$_\bigstar$)R$_\bigstar^2$', fontsize=14)
plt.legend(fontsize=12)
plt.xlim(wvl_array[0], 1.6)
plt.ylim(-1, 4)
plt.savefig('eclipse_depth_zoom_8.svg')
plt.show()

plt.figure()
plt.errorbar(wvl, np.array(eclipse_depths)*1e6, np.array(depth_yerr)*1e6, fmt='-o', label='asymmetric error')
plt.errorbar(wvl, np.array(eclipse_depths)*1e6, np.array(depth_yerr_symm)*1e6, fmt='-o', label='symmetric error')
plt.plot(wvl_array, ((planck(wvl_array*1e-6, T_planet)/planck(wvl_array*1e-6, T_star))*(R/R_star)**2)*1e6, label='with true values')
plt.plot(wvl_array, 0*np.ones(len(wvl_array)), 'k--')
plt.xlabel(r'$\lambda$ ($\mu$m)')
plt.ylabel(r'Eclipse depth (ppm)')
plt.xlim(wvl_array[0], 1.6)
plt.ylim(-1, 4)
plt.legend()
plt.show()

plt.figure()
plt.errorbar(wvl, np.array(planet_fluxes), np.vstack((planet_fluxes_minus, planet_fluxes_plus)), fmt='-o', label='asymmetric error', zorder=3)
plt.errorbar(wvl, np.array(planet_fluxes), np.vstack((planet_fluxes_minus_symm, planet_fluxes_plus_symm)), fmt='-o', label='symmetric error')
plt.plot(wvl_array, planck(wvl_array*1e-6, T_planet), label=f'B(T = {T_planet} K)')
plt.xlabel(r'$\lambda$ ($\mu$m)')
plt.ylabel(r'Blackbody(T$_p$) (W/m$^2$/sr/$\mu$m)')
plt.legend()
plt.show()

plt.figure()
plt.plot(wvl_array, planck(wvl_array*1e-6, T_star), label=fr'B(T$_\star$ = {T_star} K)')
plt.xlabel(r'$\lambda$ ($\mu$m)')
plt.ylabel(r'Blackbody(T$_\star$) (W/m$^2$/sr/$\mu$m)')
plt.legend()
plt.show()
# Out:
# ---------------------------------------------------------------------------
# IndexError                                Traceback (most recent call last)
# Cell In[11], line 18
#      15     return (2*h*c**2/lam**5) * (x*np.exp(x)) / (T*(np.exp(x)-1)**2)
#      17 for i in range(len(wvl)):
# ---> 18     T50 = Temps[i]
#      19     T16 = Temps[i] - Temps_minus[i]
#      20     T84 = Temps[i] + Temps_plus[i]
#
# IndexError: list index out of range

# %%
2.898*1e-3/T_planet
2.898*1e-3/T_star
# Out:
# np.float64(9.545454545454548e-07)

# %%
0.01*const.R_sun/const.R_earth
# Out:
# <Quantity 1.09076371>

# %%
"""import pysynphot as S
from scipy import interpolate

# LHS-1140:
Teff_LHS1140 = 3096 
Fe_H_LHS1140 = -0.15 
logg_LHS1140 = 5.041
Jmag_LHS1140 = 9.612
name_LHS1140 = 'LHS 1140'

star = S.Icat('phoenix', Teff, Fe_H, logg)  # Phoenix model
star_mJy  = star.renorm(Jmag, 'vegamag', S.ObsBandpass('johnson,j'))
star_mJy.convert('Micron')
star_mJy.convert('mjy')  # convert flux to mJy for JWST ETC input,
 
t = np.linspace(1,19,2000)
x_model_phoenix = star_mJy.wave
y_model_phoenix = star_mJy.flux
f_model_phoenix = interpolate.interp1d(x_model_phoenix,y_model_phoenix ) 
plt.plot(t, f_model_phoenix(t), alpha=0.6,label=name, color=color, linewidth=3)"""
# Out:
# "import pysynphot as S\nfrom scipy import interpolate\n\n# LHS-1140:\nTeff_LHS1140 = 3096 \nFe_H_LHS1140 = -0.15 \nlogg_LHS1140 = 5.041\nJmag_LHS1140 = 9.612\nname_LHS1140 = 'LHS 1140'\n\nstar = S.Icat('phoenix', Teff, Fe_H, logg)  # Phoenix model\nstar_mJy  = star.renorm(Jmag, 'vegamag', S.ObsBandpass('johnson,j'))\nstar_mJy.convert('Micron')\nstar_mJy.convert('mjy')  # convert flux to mJy for JWST ETC input,\n\nt = np.linspace(1,19,2000)\nx_model_phoenix = star_mJy.wave\ny_model_phoenix = star_mJy.flux\nf_model_phoenix = interpolate.interp1d(x_model_phoenix,y_model_phoenix ) \nplt.plot(t, f_model_phoenix(t), alpha=0.6,label=name, color=color, linewidth=3)"

# %%
import sys, ipywidgets, notebook
print("python:", sys.executable)
print("ipywidgets:", getattr(ipywidgets, "__version__", "not installed"))
print("notebook:", getattr(notebook, "__version__", "not installed"))
# Out:
# ---------------------------------------------------------------------------
# ModuleNotFoundError                       Traceback (most recent call last)
# Cell In[6], line 1
# ----> 1 import sys, ipywidgets, notebook
#       2 print("python:", sys.executable)
#       3 print("ipywidgets:", getattr(ipywidgets, "__version__", "not installed"))
#
# ModuleNotFoundError: No module named 'notebook'
